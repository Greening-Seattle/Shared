# %% [markdown]
# ## Section one: importing necessary packages and functions

# %%
import pandas as pd    
import geopandas as gpd
from geopandas.tools import geocode
#import geoplot
import numpy as np
import scipy.stats as stats
import scipy
import shapely
from shapely import speedups
speedups.enabled
import seaborn as sns
import matplotlib 
from matplotlib import pyplot as plt
matplotlib.rcParams.update({'font.size': 20})

import get_geodata
from get_geodata import get_gdf
from get_geodata import get_census_bounds
from get_geodata import get_zipcode_bounds

# %%
census_bounds = get_census_bounds()

# %%
census_bounds.head()
# Out:
#    NAME10    SHAPE_Area                                           geometry
# 0    25.0  1.059462e+07  POLYGON ((-122.29602 47.69023, -122.29608 47.6...
# 1    26.0  1.339838e+07  POLYGON ((-122.30817 47.69031, -122.30947 47.6...
# 2    56.0  3.212601e+07  POLYGON ((-122.39300 47.63956, -122.39421 47.6...
# 3    68.0  7.729233e+06  POLYGON ((-122.35070 47.63994, -122.35130 47.6...
# 4    60.0  1.413816e+07  POLYGON ((-122.34279 47.64320, -122.34280 47.6...

# %%
zip_bounds = get_zipcode_bounds()

# %%
zip_bounds.head()
# Out:
#                                                   geometry  NAME10  \
# ZIPCODE
# 98101    POLYGON ((-122.34598 47.60892, -122.34490 47.6...   74.02
# 98102    POLYGON ((-122.33574 47.64203, -122.33108 47.6...   74.02
# 98103    POLYGON ((-122.35808 47.69966, -122.35741 47.6...   45.00
# 98104    POLYGON ((-122.34105 47.59627, -122.34031 47.5...   84.00
# 98105    MULTIPOLYGON (((-122.32859 47.66646, -122.3285...   41.00
#
#          SHAPE_Area_left
# ZIPCODE
# 98101       1.470012e+07
# 98102       4.322189e+07
# 98103       1.440083e+08
# 98104       2.108730e+07
# 98105       9.703543e+07

# %%
gdf_15 = get_gdf(15)
gdf_15.head()
# Out:
#    YEAR    AAWDT  GEOBASID                   STNAME  SHAPE_Length  \
# 0  2015  24000.0    2028.0  W SEA BR EB 4 AV OFF RP   1458.971527
# 1  2015  38000.0    2029.0              MYERS WAY S    335.499087
# 2  2015  13000.0    2030.0          S CLOVERDALE ST    987.546181
# 3  2015  11000.0    2031.0          S CLOVERDALE ST   1305.323633
# 4  2015  12200.0    2032.0        M L KING JR WAY S    609.897683
#
#                                             geometry
# 0  LINESTRING (-122.33092 47.57152, -122.33054 47...
# 1  LINESTRING (-122.33484 47.52232, -122.33482 47...
# 2  LINESTRING (-122.32820 47.52648, -122.32961 47...
# 3  LINESTRING (-122.32292 47.52647, -122.32377 47...
# 4  LINESTRING (-122.28085 47.53540, -122.28087 47...

# %%
gdf_15.plot(figsize = (15,10))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Section two: segmenting street data by census tract

# %% [markdown]
# ### 2a: adding census tract info to street info

# %% [markdown]
# This first example is the simplest way to select a specific tract from the census bounds. Note at this point we are only using the census data and not the street data. For the example I've selected the tract where the University is located.

# %%
census_selection = census_bounds.loc[census_bounds['NAME10'] == '53.02']

# %%
census_selection
# Out:
#     OBJECTID  TRACT TRACTCE10      GEOID10 NAME10          NAMELSAD10  \
# 84       128   5302    005302  53033005302  53.02  Census Tract 53.02
#
#     ACRES_TOTAL  WATER  SHAPE_Length    SHAPE_Area  \
# 84   577.317916      0  33889.310995  2.514797e+07
#
#                                              geometry
# 84  POLYGON ((-122.30653 47.66126, -122.30725 47.6...

# %% [markdown]
# The following is just a plot of all of the census tracts in gray with a plot of the selected census tract overlaid in red.

# %%
fig, ax = plt.subplots(figsize = (8, 16))

census_bounds.plot(ax=ax, facecolor='gray')
census_selection.plot(ax=ax, facecolor='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now we can start to segment the street data by census tract. This first method is best for just individual selections and is probably not the most efficient. You can generate a boolean mask using the census selection and then use it to filter the street data.

# %%
Udist_mask = gdf_15.within(census_selection.at[84, 'geometry'])
print(Udist_mask)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1855    False
# 1856    False
# 1857    False
# 1858    False
# 1859    False
# Length: 1860, dtype: bool

# %%
Udist_data = gdf_15.loc[Udist_mask]
Udist_data.describe()
# Out:
#               AAWDT     GEOBASID  SHAPE_Length
# count     30.000000    30.000000     30.000000
# mean   14215.277520  1415.233333    536.509590
# std    11912.652166   152.400037    553.674731
# min     2200.000000  1307.000000     82.251670
# 25%     4225.000000  1363.250000    247.449472
# 50%    12145.700974  1388.500000    291.558616
# 75%    21000.000000  1402.750000    692.835239
# max    43594.803000  1961.000000   2966.829559

# %%
Udist_data.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The better way to do this in my opinion is to join the census data with the street data - then all street data will have its associated census tractk, and you can select specific census tracts by indexing the dataframe. Here is the code to do that:

# %%
tracts_by_street = gpd.sjoin(gdf_15, census_bounds, op='within')
tracts_by_street.head()
# Out:
#     YEAR      AAWDT  GEOBASID                   STNAME  SHAPE_Length_left  \
# 0   2015  24000.000    2028.0  W SEA BR EB 4 AV OFF RP        1458.971527
# 9   2015  10000.000    2040.0          S SPOKANE CR ST          74.907110
# 28  2015   2000.000    2002.0          4TH AV NB ON RP         362.035102
# 29  2015   7000.000    2003.0            AIRPORT WAY S         480.942822
# 32  2015  10059.796    2006.0      EAST MARGINAL WAY S        1422.024871
#
#                                              geometry  index_right  OBJECTID  \
# 0   LINESTRING (-122.33092 47.57152, -122.33054 47...           97       141
# 9   LINESTRING (-122.32599 47.57156, -122.32569 47...           97       141
# 28  LINESTRING (-122.32905 47.58934, -122.32926 47...           97       141
# 29  LINESTRING (-122.32248 47.59018, -122.32248 47...           97       141
# 32  LINESTRING (-122.33968 47.57170, -122.33969 47...           97       141
#
#     TRACT TRACTCE10      GEOID10 NAME10       NAMELSAD10  ACRES_TOTAL  WATER  \
# 0    9300    009300  53033009300     93  Census Tract 93  2341.806557      0
# 9    9300    009300  53033009300     93  Census Tract 93  2341.806557      0
# 28   9300    009300  53033009300     93  Census Tract 93  2341.806557      0
# 29   9300    009300  53033009300     93  Census Tract 93  2341.806557      0
# 32   9300    009300  53033009300     93  Census Tract 93  2341.806557      0
#
#     SHAPE_Length_right    SHAPE_Area
# 0         53536.277831  1.020091e+08
# 9         53536.277831  1.020091e+08
# 28        53536.277831  1.020091e+08
# 29        53536.277831  1.020091e+08
# 32        53536.277831  1.020091e+08

# %%
university_2015 = tracts_by_street.loc[tracts_by_street['NAME10'] == '53.02']

# %%
university_2015
# Out:
#      YEAR         AAWDT  GEOBASID             STNAME  SHAPE_Length_left  \
# 64   2015  21672.120640    1960.0      NE PACIFIC ST         426.892327
# 65   2015  24000.000000    1961.0    EASTLAKE AVE NE         225.306037
# 561  2015  43594.803000    1412.0   MONTLAKE BLVD NE        2966.829559
# 572  2015  31500.000000    1423.0   MONTLAKE BLVD NE         575.275702
# 573  2015  19500.000000    1424.0        25TH AVE NE         560.713939
# 574  2015   5500.000000    1425.0         NE 44TH ST         241.814169
# 575  2015  36000.000000    1428.0   MONTLAKE BLVD NE         495.856467
# 598  2015   2500.000000    1403.0     NE CAMPUS PKWY         285.005152
# 612  2015  14000.000000    1363.0        15TH AVE NE         878.010612
# 613  2015   4000.000000    1364.0  UNIVERSITY WAY NE         712.956092
# 614  2015   3700.000000    1365.0  UNIVERSITY WAY NE         280.026740
# 615  2015   4600.000000    1366.0    BROOKLYN AVE NE         645.301811
# 616  2015   3700.000000    1367.0  UNIVERSITY WAY NE         285.017424
# 629  2015  16000.000000    1384.0        15TH AVE NE         231.722763
# 630  2015   4000.000000    1385.0  UNIVERSITY WAY NE         231.282065
# 631  2015   2700.000000    1386.0     NE CAMPUS PKWY         278.949829
# 635  2015   6000.000000    1391.0    BROOKLYN AVE NE         230.694834
# 636  2015   4200.000000    1392.0     NE CAMPUS PKWY         285.006100
# 638  2015   4300.000000    1395.0     NE CAMPUS PKWY         708.679715
# 639  2015  16000.000000    1399.0        15TH AVE NE          84.034664
# 640  2015   4500.000000    1400.0  UNIVERSITY WAY NE          83.081820
# 641  2015   2200.000000    1401.0     NE CAMPUS PKWY         279.943280
# 642  2015   6000.000000    1402.0    BROOKLYN AVE NE          82.251670
# 649  2015  25500.000000    1323.0      NE PACIFIC ST        1488.547356
# 657  2015  17500.000000    1335.0      NE PACIFIC ST         264.355384
# 658  2015  15500.000000    1336.0      NE PACIFIC ST         298.099808
# 659  2015  16500.000000    1337.0      NE PACIFIC ST         717.861643
# 690  2015  21500.000000    1307.0      NE PACIFIC ST         508.017920
# 694  2015  10291.401949    1311.0      NE PACIFIC PL         958.722889
# 695  2015  39500.000000    1312.0   MONTLAKE BLVD NE         785.029916
#
#                                               geometry  index_right  OBJECTID  \
# 64   LINESTRING (-122.30597 47.64970, -122.30515 47...           84       128
# 65   LINESTRING (-122.31784 47.65602, -122.31797 47...           84       128
# 561  LINESTRING (-122.30114 47.65898, -122.30207 47...           84       128
# 572  LINESTRING (-122.30001 47.66035, -122.30004 47...           84       128
# 573  LINESTRING (-122.30114 47.65898, -122.30106 47...           84       128
# 574  LINESTRING (-122.30091 47.66051, -122.30028 47...           84       128
# 575  LINESTRING (-122.29834 47.66109, -122.29847 47...           84       128
# 598  LINESTRING (-122.31326 47.65622, -122.31442 47...           84       128
# 612  LINESTRING (-122.31246 47.65298, -122.31234 47...           84       128
# 613  LINESTRING (-122.31333 47.65340, -122.31333 47...           84       128
# 614  LINESTRING (-122.31328 47.65535, -122.31215 47...           84       128
# 615  LINESTRING (-122.31449 47.65360, -122.31448 47...           84       128
# 616  LINESTRING (-122.31328 47.65535, -122.31444 47...           84       128
# 629  LINESTRING (-122.31214 47.65598, -122.31215 47...           84       128
# 630  LINESTRING (-122.31327 47.65599, -122.31328 47...           84       128
# 631  LINESTRING (-122.31214 47.65598, -122.31327 47...           84       128
# 635  LINESTRING (-122.31442 47.65600, -122.31444 47...           84       128
# 636  LINESTRING (-122.31327 47.65599, -122.31442 47...           84       128
# 638  LINESTRING (-122.31442 47.65600, -122.31557 47...           84       128
# 639  LINESTRING (-122.31213 47.65621, -122.31214 47...           84       128
# 640  LINESTRING (-122.31326 47.65622, -122.31326 47...           84       128
# 641  LINESTRING (-122.31213 47.65621, -122.31326 47...           84       128
# 642  LINESTRING (-122.31442 47.65623, -122.31442 47...           84       128
# 649  LINESTRING (-122.31246 47.65298, -122.31210 47...           84       128
# 657  LINESTRING (-122.31246 47.65298, -122.31333 47...           84       128
# 658  LINESTRING (-122.31333 47.65340, -122.31334 47...           84       128
# 659  LINESTRING (-122.31449 47.65360, -122.31686 47...           84       128
# 690  LINESTRING (-122.30762 47.65054, -122.30759 47...           84       128
# 694  LINESTRING (-122.30762 47.65054, -122.30754 47...           84       128
# 695  LINESTRING (-122.30459 47.64900, -122.30458 47...           84       128
#
#      TRACT TRACTCE10      GEOID10 NAME10          NAMELSAD10  ACRES_TOTAL  \
# 64    5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 65    5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 561   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 572   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 573   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 574   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 575   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 598   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 612   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 613   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 614   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 615   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 616   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 629   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 630   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 631   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 635   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 636   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 638   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 639   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 640   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 641   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 642   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 649   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 657   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 658   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 659   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 690   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 694   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
# 695   5302    005302  53033005302  53.02  Census Tract 53.02   577.317916
#
#      WATER  SHAPE_Length_right    SHAPE_Area
# 64       0        33889.310995  2.514797e+07
# 65       0        33889.310995  2.514797e+07
# 561      0        33889.310995  2.514797e+07
# 572      0        33889.310995  2.514797e+07
# 573      0        33889.310995  2.514797e+07
# 574      0        33889.310995  2.514797e+07
# 575      0        33889.310995  2.514797e+07
# 598      0        33889.310995  2.514797e+07
# 612      0        33889.310995  2.514797e+07
# 613      0        33889.310995  2.514797e+07
# 614      0        33889.310995  2.514797e+07
# 615      0        33889.310995  2.514797e+07
# 616      0        33889.310995  2.514797e+07
# 629      0        33889.310995  2.514797e+07
# 630      0        33889.310995  2.514797e+07
# 631      0        33889.310995  2.514797e+07
# 635      0        33889.310995  2.514797e+07
# 636      0        33889.310995  2.514797e+07
# 638      0        33889.310995  2.514797e+07
# 639      0        33889.310995  2.514797e+07
# 640      0        33889.310995  2.514797e+07
# 641      0        33889.310995  2.514797e+07
# 642      0        33889.310995  2.514797e+07
# 649      0        33889.310995  2.514797e+07
# 657      0        33889.310995  2.514797e+07
# 658      0        33889.310995  2.514797e+07
# 659      0        33889.310995  2.514797e+07
# 690      0        33889.310995  2.514797e+07
# 694      0        33889.310995  2.514797e+07
# 695      0        33889.310995  2.514797e+07

# %%
university_2015.plot()
# Out:
# <AxesSubplot:>

# %%
tracts_by_street_diss = tracts_by_street.dissolve(by='NAME10')

# %% [markdown]
# ### 2b: Aggregating street info by census tract

# %% [markdown]
# Finally, we can aggregate the street info by census tract for better visualization.

# %%
city_by_zip = gpd.sjoin(zip_bounds, gdf_15, op='intersects')

# %%
gdf_15.describe()
# Out:
#                AAWDT     GEOBASID  SHAPE_Length
# count    1860.000000  1859.000000   1860.000000
# mean    12210.741481  1031.557827   1337.628768
# std      9907.991638   585.419003   1382.193543
# min       600.000000     3.000000     48.541264
# 25%      5500.000000   540.500000    365.229349
# 50%      9770.436000  1021.000000    834.996772
# 75%     16000.000000  1537.500000   1792.337167
# max    108178.569998  4493.000000  13076.444950

# %%
city_by_zip.head()
# Out:
#                                                   geometry  NAME10  \
# ZIPCODE
# 98101    POLYGON ((-122.34598 47.60892, -122.34490 47.6...   74.02
# 98121    POLYGON ((-122.36110 47.61854, -122.36095 47.6...   81.00
# 98101    POLYGON ((-122.34598 47.60892, -122.34490 47.6...   74.02
# 98121    POLYGON ((-122.36110 47.61854, -122.36095 47.6...   81.00
# 98101    POLYGON ((-122.34598 47.60892, -122.34490 47.6...   74.02
#
#          SHAPE_Area_left  index_right  YEAR         AAWDT  GEOBASID  \
# ZIPCODE
# 98101       1.470012e+07         1163  2015  10639.335836     800.0
# 98121       1.225219e+07         1163  2015  10639.335836     800.0
# 98101       1.470012e+07         1186  2015   2500.000000     823.0
# 98121       1.225219e+07         1186  2015   2500.000000     823.0
# 98101       1.470012e+07         1197  2015  11000.000000     705.0
#
#               STNAME  SHAPE_Length
# ZIPCODE
# 98101    ALASKAN WAY   1245.144941
# 98121    ALASKAN WAY   1245.144941
# 98101    VIRGINIA ST    372.729354
# 98121    VIRGINIA ST    372.729354
# 98101    ALASKAN WAY    613.438180

# %%
fig, ax = plt.subplots(figsize=(15,10))
zip_bounds.plot(ax=ax, facecolor='none', edgecolor='k')
gdf_15.plot(ax=ax, color='blue')
plt.axis('off')
plt.show()

# %%
city_by_zip.plot(edgecolor='white', figsize=(15,10))
plt.axis('off')
plt.show()

# %%
sarahs_house = city_by_tract.loc[city_by_tract['NAME10'] == '51']

# %%
sarahs_house.head()
# Out:
#     OBJECTID  TRACT TRACTCE10      GEOID10 NAME10       NAMELSAD10  \
# 43        84   5100    005100  53033005100     51  Census Tract 51
# 43        84   5100    005100  53033005100     51  Census Tract 51
# 43        84   5100    005100  53033005100     51  Census Tract 51
# 43        84   5100    005100  53033005100     51  Census Tract 51
# 43        84   5100    005100  53033005100     51  Census Tract 51
#
#     ACRES_TOTAL  WATER  SHAPE_Length_left    SHAPE_Area  \
# 43   217.863647      0       13462.590731  9.490140e+06
# 43   217.863647      0       13462.590731  9.490140e+06
# 43   217.863647      0       13462.590731  9.490140e+06
# 43   217.863647      0       13462.590731  9.490140e+06
# 43   217.863647      0       13462.590731  9.490140e+06
#
#                                              geometry  index_right  YEAR  \
# 43  POLYGON ((-122.32827 47.66500, -122.32906 47.6...          620  2015
# 43  POLYGON ((-122.32827 47.66500, -122.32906 47.6...          628  2015
# 43  POLYGON ((-122.32827 47.66500, -122.32906 47.6...          510  2015
# 43  POLYGON ((-122.32827 47.66500, -122.32906 47.6...          486  2015
# 43  POLYGON ((-122.32827 47.66500, -122.32906 47.6...          627  2015
#
#            AAWDT  GEOBASID             STNAME  SHAPE_Length_right
# 43  11227.385174    1374.0      NE PACIFIC ST         4571.349948
# 43  12802.605000    1383.0          N 40TH ST         2325.627711
# 43  22547.056000    1458.0         NE 45TH ST         1857.804215
# 43  24607.640000    1521.0         NE 50TH ST         1871.015826
# 43   4044.291412    1382.0  WALLINGFORD AVE N         2353.939940

# %%
sarahs_house.plot()
# Out:
# <AxesSubplot:>

# %%
test = sarahs_house['AAWDT'].sum()

# %%
traffic_zones = city_by_zip.dissolve(by='ZIPCODE', aggfunc = sum)

# %%
traffic_zones.reset_index(inplace = True)

# %%
traffic_zones.describe()
# Out:
#            OBJECTID         TRACT    ACRES_TOTAL  WATER  SHAPE_Length_left  \
# count    134.000000  1.340000e+02     134.000000  134.0       1.340000e+02
# mean    2279.089552  1.423019e+05    9905.774565    0.0       4.692653e+05
# std     2895.118467  1.769169e+05   26330.069445    0.0       7.157692e+05
# min       10.000000  9.000000e+02      31.812502    0.0       1.194697e+04
# 25%      576.000000  3.350450e+04    2770.313241    0.0       1.647922e+05
# 50%     1385.000000  9.681000e+04    4706.502710    0.0       2.633827e+05
# 75%     2848.000000  1.692000e+05    9723.364074    0.0       5.379787e+05
# max    17343.000000  1.143900e+06  288042.206558    0.0       6.584962e+06
#
#          SHAPE_Area    index_right         AAWDT       GEOBASID  \
# count  1.340000e+02     134.000000  1.340000e+02     134.000000
# mean   4.314955e+08   18939.873134  2.601562e+05   22229.917910
# std    1.146938e+09   25320.967471  2.645114e+05   21387.008914
# min    1.385753e+06     779.000000  2.944862e+04     251.000000
# 25%    1.206748e+08    3625.750000  9.859430e+04    9230.250000
# 50%    2.050153e+08   12239.000000  1.888396e+05   16668.000000
# 75%    4.235497e+08   22716.250000  2.994776e+05   28345.000000
# max    1.254712e+10  174199.000000  1.890148e+06  103356.000000
#
#        SHAPE_Length_right
# count          134.000000
# mean         32911.771931
# std          19007.845936
# min           7778.973253
# 25%          21964.449617
# 50%          28738.942680
# 75%          40537.458903
# max         163153.529192

# %%
traffic_zones = traffic_zones[['NAME10','geometry', 'AAWDT' ]]

# %%
traffic_zones.head()
# Out:
#            NAME10                                           geometry  \
# ZIPCODE
# 98101    13323.60  POLYGON ((-122.34598 47.60892, -122.34490 47.6...
# 98102     2738.74  POLYGON ((-122.33574 47.64203, -122.33108 47.6...
# 98103     5670.00  POLYGON ((-122.35808 47.69966, -122.35741 47.6...
# 98104    13944.00  POLYGON ((-122.34105 47.59627, -122.34031 47.5...
# 98105     6560.00  MULTIPOLYGON (((-122.32859 47.66646, -122.3285...
#
#                 AAWDT
# ZIPCODE
# 98101    1.877668e+06
# 98102    4.782904e+05
# 98103    1.880369e+06
# 98104    1.847450e+06
# 98105    1.762661e+06

# %%
traffic_zones['NAME10'].value_counts()
# Out:
# 10       1
# 76       1
# 118      1
# 8        1
# 87       1
#         ..
# 103      1
# 43.02    1
# 71       1
# 88       1
# 92       1
# Name: NAME10, Length: 134, dtype: int64

# %%
test_frame = traffic_zones[traffic_zones['NAME10'] == '51']

# %%
test_frame['AAWDT'] == test
# Out:
# 77    True
# Name: AAWDT, dtype: bool

# %%
ave_traffic = traffic_zones['AAWDT']
#scheme = mapclassify.NaturalBreaks(ave_traffic, k=10)
geoplot.choropleth(traffic_zones, hue=ave_traffic, cmap='rainbow', legend = True)
plt.show()
